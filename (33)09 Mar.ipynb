# %% [markdown]
# #                                                                           Statistics Advance-2

# %% [markdown]
# #  Q.1 What are the Probability Mass Function(PMF) and Probability Density Function(PDF)? Explain with an example.

# %% [markdown]
# ## What are the Probability Mass Function(PMF)

# %% [raw]
# The Probability Mass Function (PMF) is a fundamental concept in probability theory and statistics, particularly for discrete random variables. It describes the probability
# distribution of a discrete random variable by assigning probabilities to each possible outcome.
#
# Here are key points about the PMF:
#
# 1.Definition:
#
#             The PMF gives the probability of a discrete random variable taking on a specific value.
#
# 2.Discrete Variables:
#
#                     It is applicable to random variables that can only take on a countable set of distinct values (e.g., whole numbers).
#
# 3.Non-Negative Probabilities:
#
#                             The PMF must always return non-negative probabilities for all possible values of the random variable.
#
# 4.Probability Sum:
#
#                 The sum of all probabilities in the PMF over the entire range of possible values is equal to 1.
#
# 5.Example:
#
#             Consider rolling a six-sided die. The PMF of the outcome 'X' would be P(X=x)==1/6 for x=1,2,3,4,5,6.
#
# 6.Cumulative Distribution Function (CDF):
#
#                                         The PMF is related to the Cumulative Distribution Function (CDF), which gives the probability of the random variable being less
#                                         than or equal to a certain value.
#
# 7.Example with Coin Toss:
#
#                         For a fair coin toss (H for heads, T for tails), the PMF is P(X=H)==1/2 and P(X=T)==1/2
#
# 8.Notation:
#
#             The PMF is denoted as P(X=x), which represents the probability of the random variable 'X' taking on the value 'x'.
#
#
#
#
# The PMF is a critical tool for understanding and analyzing the behavior of discrete random variables. It allows us to calculate probabilities associated with specific outcomes
# and is foundational in various statistical applications, including hypothesis testing, decision theory, and more.
#
#
#  Here are some additional points and advanced knowledge about the Probability Mass Function (PMF):
#
# 9.Point Probabilities:
#
#                         The PMF provides the probability of exact values that a discrete random variable can take. For example, in the case of rolling a fair six-sided die,
#                         the PMF gives the probability of obtaining each face value (1, 2, 3, 4, 5, or 6).
#
# 10.Graphical Representation:
#
#                             The PMF can be visually represented as a bar graph, with the possible values of the random variable on the x-axis and their associated probabilities
#                             on the y-axis.
#
# 11.Expected Value (Mean):
#
#                         The expected value (mean) of a discrete random variable is calculated as the weighted sum of all possible values, where the weights are their respective
#                         probabilities according to the PMF.
#
# 12.Variance:
#
#             The variance of a discrete random variable is a measure of its spread or variability. It is calculated as the weighted sum of the squared differences between each
#             possible value and the mean, where the weights are their respective probabilities according to the PMF.
#
# 13.Support:
#
#             The set of all possible values that a random variable can take is called its support. The PMF is defined only for values within the support.
#
#
# 14.Zero Probability:
#
#                     The PMF assigns zero probability to values outside the support. This means that any value not in the support cannot occur according to the random
#                     variable's distribution.
#
# 15.Piecewise Functions:
#
#                         Some random variables may have PMFs that are defined by different functions for different ranges of values. These are known as piecewise PMFs.
#
# 16.Multinomial Distribution:
#
#                             For situations involving multiple categories or outcomes, the Multinomial distribution generalizes the concept of the PMF.
#
# 17.Probability Generating Function (PGF):
#
#                                         The PGF is a function that fully characterizes the PMF of a random variable. It is a powerful tool in probability theory.
#
#
#
#         The PMF is a fundamental concept in probability theory and is used extensively in various fields, including statistics, engineering, economics, and more.
#          Understanding the PMF allows for precise modeling and analysis of discrete random variables and their associated probabilities.

# %% [markdown]
# ## example

# %% [raw]
# A Probability Mass Function (PMF) is a function that describes the probability of a discrete random variable taking on a specific value. In other words, it gives the probability
# of each possible outcome in a discrete probability distribution.
#
# Here's a more detailed explanation with an example:
#
# A... Example: Rolling a Six-Sided Die
#                                  Let's consider the example of rolling a fair six-sided die. The possible outcomes are {1, 2, 3, 4, 5, 6}, and each outcome has a probability of 1/6
#                                     of occurring, assuming the die is fair.
#
#
# The PMF for this example can be represented as follows:
#
# P(X=k)= 1/6  for k=1,2,3,4,5,6
#
# Here,
#         P(X=k) represents the probability of getting a specific value k when rolling the die. In this case, the probability is always 1/6 for each possible outcome.
#
# B... Properties of PMF:
#                     1. Non-negativity:
#
#                                         P(X=k) is non-negative for all possible values of k.
#
#                     2. Sum of Probabilities:
#                                             The sum of probabilities for all possible values of k must equal 1.
#                                             ∑P(X=k)=1
#
# C... Usage:
# PMFs are particularly useful in scenarios involving discrete random variables. They allow us to calculate the probabilities of specific events occurring.
#
# For example, in the die rolling example, we can use the PMF to answer questions like "What is the probability of rolling an even number?" This would be
# P(X=2)+P(X=4)+P(X=6)= 1/6 +1/6 +1/6 =1/2
#
#
#
# D... Summary:
#
# A Probability Mass Function (PMF) describes the probability of a discrete random variable taking on specific values.
# It assigns probabilities to individual outcomes in a discrete sample space.
# The PMF must satisfy two properties: non-negativity and the sum of probabilities equals 1.
# Remember, PMFs are specific to discrete random variables. For continuous random variables, we use Probability Density Functions (PDFs) instead.

# %% [markdown]
# ## Probability Density Function(PDF)?

# %% [raw]
# A Probability Density Function (PDF) is a function that describes the probability of a continuous random variable falling within a certain range of values.
# Unlike a Probability Mass Function (PMF) which is used for discrete random variables, a PDF is used for continuous random variables.
#
# Let's go through an example to illustrate this:
#
# A... Example: Heights of Students
# Suppose we have a class of students, and we're interested in the heights. We can assume that the heights are continuous, meaning they can take any value within a certain range
# (e.g., from 140 cm to 190 cm).
#
# Now, let's say we plot the probability density of heights using a PDF. The PDF might look something like a smooth curve, perhaps resembling a bell-shaped curve
# (which is often associated with a normal distribution).
#
# The key point here is that the area under the curve within a certain range represents the probability of the random variable falling within that range.
#
# B... Properties of PDF:
#                         1. Non-negativity:
#                                             The PDF is always non-negative.
#
#                         2. Area under the Curve:
#                                                     The total area under the PDF curve over the entire range of possible values equals 1.
#
# C... Usage:
#             PDFs are used to model continuous random variables and are crucial in various fields such as statistics, engineering, and physics. They allow us to calculate probabilities
#             of continuous events.
#
# For example, with the PDF of heights, we can answer questions like "What is the probability that a randomly selected student has a height between 160 cm and 170 cm?"
# We calculate this by finding the area under the curve between those two points.
#
# C... Summary:
#             A Probability Density Function (PDF) describes the probability of a continuous random variable falling within a specific range of values.
#             It's represented by a curve, and the area under the curve within a certain range represents the probability of the random variable falling within that range.
#             The PDF must satisfy two properties: non-negativity and the total area under the curve equals 1.
#
# Remember, PDFs are specific to continuous random variables. For discrete random variables, we use Probability Mass Functions (PMFs) instead.

# %% [markdown]
# # Q.2 What is Cumulative Density Function(CDF)? Explain with an example. Why CDF is used?

# %% [markdown]
# ## What is Cumulative Density Function(CDF)?

# %% [raw]
# The Cumulative Distribution Function (CDF) gives the probability that a random variable is less than or equal to a specific value.
# It's a non-decreasing function that ranges from 0 to 1. For a discrete variable, it's the sum of probabilities up to a point, and for a continuous variable,
# it's the integral of the probability density function up to a point.

# %% [markdown]
# ## Explain with an example.

# %% [raw]
# Example:
#             Rolling a Six-Sided Die
#
#
# Suppose we have a fair six-sided die.
#                                     The possible outcomes are {1, 2, 3, 4, 5, 6}, and each outcome is equally likely. The CDF for this example can be calculated as follows:
#
# For a discrete random variable, the CDF at a specific point x is the probability of getting a value less than or equal to
# x. In this case, we can express the CDF as:
#
# F(x)=P(X≤x)
#
# Let's calculate it:
#
# F(1)=P(X≤1)=P(X=1)= 1/6
# F(2)=P(X≤2)=P(X=1 or X=2)= 2/6
# F(3)=P(X≤3)=P(X=1,2 or 3)= 3/6
# F(4)=P(X≤4)=P(X=1,2,3 or 4)=4/6
# F(5)=P(X≤5)=P(X=1,2,3,4 or 5)=5/6
# F(6)=P(X≤6)=P(X=1,2,3,4,5 or 6)=6/6
# This gives us the cumulative probabilities for each possible value.
#
# A... Properties:
#
# 1. The CDF is non-decreasing:
#                         F(x_1)≤F(x-2)  if x_1 ≤ x_2
#
# 2. The CDF ranges from 0 to 1: 0 ≤ F(x) ≤ 1.
#
# As x approaches negative infinity, F(x) approaches 0. As x approaches positive infinity,
# F(x) approaches 1.
#
# B... Interpretation:
# In this example,
# F(x) at a specific value x tells us the probability of getting a result less than or equal to
# x when rolling the die. For instance, F(4)= 2/3 indicates a 2/3 probability of getting a value of 4 or less.
#
# This is how the Cumulative Density Function provides a cumulative view of the probabilities associated with a random variable.

# %% [markdown]
# ## Why CDF is used?

# %% [raw]
# The Cumulative Density Function (CDF) is used for several important reasons in probability theory and statistics:
#
#   1. Probability Computation:
#
#                             The CDF provides a convenient way to compute probabilities of events involving random variables. It gives the cumulative probability up to a specified point,
#                             which can be used to find the probability of ranges or specific values.
#
#     2.Understanding Cumulative Behavior:
#
#                                         The CDF allows us to see how the probability of a random variable taking on values less than or equal to a specified point accumulates as we
#                                         move along the range of possible values.
#
#     3. Comparison of Random Variables:
#
#                                     By comparing the CDFs of different random variables, we can make inferences about their relative likelihoods or distributions.
#
#     4. Quantifying Uncertainty:
#
#                                 The CDF provides a way to quantify uncertainty about the values that a random variable can take. It gives a full picture of the distribution.
#
#     5. Hypothesis Testing:
#
#                             In hypothesis testing, the CDF plays a crucial role in determining critical values and significance levels.
#
#     6.Finding Percentiles (Quantiles):
#
#                                     The inverse of the CDF, known as the quantile function, helps find values that correspond to specific probabilities. This is particularly useful
#                                     in applications like finance, where percentiles are important.
#
#     7.Calculating Expected Values:
#
#                                 The CDF is used in calculating the expected value (mean) of a random variable. The expected value is found by integrating the random variable
#                                 weighted by the CDF.
#
#     8. Modeling and Simulation:
#
#                                 CDFs are fundamental for creating models and conducting simulations to understand and predict various real-world phenomena.
#
#     9. Continuous and Discrete Distributions:
#
#                                             The concept of a CDF is applicable to both continuous and discrete random variables, providing a unified framework for dealing with
#                                             different types of random variables.
#     10.Risk Assessment:
#
#                         In fields like finance and insurance, understanding the cumulative probabilities associated with different events is critical for assessing risks and
#                         making informed decisions.
#
#     In summary, the CDF is a powerful tool in probability theory and statistics that aids in the analysis, interpretation, and modeling of random variables.
#     It provides a comprehensive view of the distribution's behavior, allowing for a wide range of applications in diverse fields.

# %% [markdown]
# # Q.3 What are some examples of situations where the normal distribution might be used as a model?
# #       Explain how the parameters of the normal distribution relate to the shape of the distribution.

# %% [markdown]
# # What are some examples of situations where the normal distribution might be used as a model?

# %% [raw]
# The normal distribution, also known as the Gaussian distribution, is widely used to model various phenomena in different fields due to its mathematical tractability
# and its applicability to a wide range of natural phenomena. Here are some examples of situations where the normal distribution might be used as a model:
#
# 1. Height of a Population:
#                             The heights of a large population are often approximately normally distributed. This is known as the "bell curve" phenomenon.
#
# 2. IQ Scores:
#                 Intelligence Quotient (IQ) scores in a population tend to follow a normal distribution.
#
# 3. Errors in Measurements:
#                             Many types of measurement errors (e.g., in manufacturing processes, scientific experiments) tend to be normally distributed.
#
# 4. Blood Pressure:
#                     Blood pressure measurements in a large, healthy population can often be modeled using a normal distribution.
#
# 5. Astronomical Data:
#                     Some astronomical measurements, such as the brightness of stars, can be well-described by a normal distribution.
#
# 6. Economics:
#                 In economic theory, the distribution of individual income is often assumed to be log-normal, which is a related distribution to the normal distribution.
#
# 7. Test Scores:
#                 In educational testing, scores on standardized tests like the SAT or GRE often approximate a normal distribution.
#
# 8. Financial Markets:
#                     In finance, some models assume that returns on investments are normally distributed.
#
# 9. Biological Traits:
#                     Certain biological traits like the weight of seeds from a plant, the length of fish in a population, etc., can be modeled using a normal distribution.
#
# 10. Natural Phenomena:
#                         Many natural phenomena, such as the distribution of wind speeds, the distribution of particle velocities in a gas, and more, can be modeled using a
#                         normal distribution.
#
# 11. Psychometrics:
#                     Various psychological and sociological variables, such as personality traits or social attitudes, may be modeled using a normal distribution.
#
# Quality Control: In manufacturing, the distribution of product measurements (e.g., dimensions, weights) is often assumed to be normal for statistical process control.
#
# It's important to note that while the normal distribution is a useful approximation for many real-world phenomena, there are cases where other distributions may be more appropriate.
# Additionally, in practice, real data may not always perfectly follow a normal distribution, but it can still be a useful approximation.

# %% [markdown]
# # Explain how the parameters of the normal distribution relate to the shape of the distribution.

# %% [raw]
# The normal distribution is characterized by two parameters: the mean (μ) and the standard deviation (σ). These parameters play a crucial role in determining the shape,
# location, and spread of the distribution.
#
# 1.Mean (μ):
#
#             The mean determines the central location of the distribution. It is the point around which the data is centered.
#             The highest point of the normal distribution (the peak of the bell curve) occurs at the mean.
#             Shifting the mean to the right or left will result in the entire distribution shifting in the same direction.
#
#         Effect on the Distribution:
#
#                                 1. If μ increases, the distribution shifts to the right.
#                                 2. If μ decreases, the distribution shifts to the left.
#
# 2. Standard Deviation (σ):
#
#             The standard deviation measures the spread or dispersion of the data points from the mean.
#             A smaller standard deviation indicates that the data points are clustered closely around the mean.
#             A larger standard deviation indicates that the data points are spread out over a wider range of values.
#
#     Effect on the Distribution:
#
#                                 1. If σ increases, the distribution becomes wider and flatter.
#                                 2. If σ decreases, the distribution becomes narrower and taller.
#
# Note:
#     When σ is small, the data is tightly clustered around the mean, and when σ is large, the data is more spread out.
#
# In summary, the mean determines the center of the distribution, while the standard deviation determines the spread. Together, they shape the normal distribution.
# Adjusting these parameters allows us to model a wide variety of real-world phenomena with this versatile distribution.

# %% [markdown]
# # Q.4 Explain the importance of Normal Distribution. Give a few real-life examples of Normal Distribution?

# %% [markdown]
# ## Explain the importance of Normal Distribution.

# %% [raw]
# The Normal Distribution, also known as the Gaussian distribution, holds significant importance in various fields due to several compelling reasons:
#
# 1.Common Natural Phenomena:
#
#                             Many natural phenomena, such as height, weight, IQ scores, blood pressure, and various biological attributes, tend to follow a normal distribution.
#                             Understanding this distribution allows us to model and analyze these phenomena accurately.
#
# 2. Central Limit Theorem (CLT):
#
#                                 The Central Limit Theorem states that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases,
#                                 regardless of the shape of the population distribution. This property is crucial for statistical inference and hypothesis testing.
#
#   3. Statistical Inference:
#
#                             In statistics, many hypothesis tests, confidence intervals, and regression models assume that the data follows a normal distribution.
#                             Deviations from normality can impact the validity of these statistical methods.
#
# 4. Parameter Estimation:
#
#                         Maximum Likelihood Estimation (MLE) and other estimation techniques often assume a normal distribution. This distribution provides a reference point
#                         for estimating population parameters.
#
# 5.Control Limits in Quality Control:
#
#                                     In quality control, control charts (like the X-bar chart and S chart) are used to monitor processes. These charts are based on the assumption
#                                     of normally distributed data.
#
# 6.Economic and Financial Applications:
#
#                                         Many economic models and financial theories assume normality, particularly in options pricing, portfolio management, risk assessment,
#                                         and asset pricing models.
#
# 7.Psychometric Testing:
#
#                         In psychology, the normal distribution is used as a benchmark for evaluating and interpreting scores on various psychological tests.
#
# 8.Natural Variation in Biological Systems:
#
#                                             Biological attributes, such as body measurements, enzyme activity, and physiological characteristics, often exhibit a normal distribution
#                                             due to the complex interplay of genetic and environmental factors.
#
# 9.Machine Learning and Data Science:
#
#                                     In machine learning, algorithms and techniques (like linear regression, ANOVA, and clustering) often assume normality or make use of
#                                     the central limit theorem.
#
# 10.Risk Assessment and Management:
#
#                                 In risk analysis, the normal distribution is commonly used to model various financial and environmental risks. It provides a basis for calculating
#                                 probabilities of extreme events.
#
# 11.Predictive Modeling:
#
#                         Normal distribution assumptions underlie many predictive modeling techniques, including linear regression and time series analysis.
#
# 12.Statistical Process Control:
#
#                                 In manufacturing and process industries, normality assumptions are fundamental for controlling and improving processes.
#
#
#     In summary, the normal distribution is a foundational concept in statistics and has wide-ranging applications in various scientific, engineering, economic, and social disciplines.
#     Its properties make it a useful reference point for understanding and analyzing data in many fields of study.

# %% [markdown]
# ## Give a few real-life examples of Normal Distribution?

# %% [raw]
# The Normal Distribution, also known as the Gaussian distribution, is a fundamental concept with many real-life applications. Here are a few examples:
#
#
#     1.Human Height:
#
#                 The distribution of human heights tends to follow a roughly normal distribution. Most people fall near the average height, with fewer individuals being very tall
#                 or very short.
#
#     2. IQ Scores:
#
#                 IQ scores are designed to follow a normal distribution with a mean of 100 and a standard deviation of 15. This distribution allows for comparisons of cognitive
#                 abilities across a population.
#
#     3.Blood Pressure:
#
#                     Blood pressure measurements in a healthy population tend to follow a normal distribution. The systolic and diastolic pressures cluster around their respective means.
#
#     4. Error in Measurement:
#
#                             When we make measurements using instruments (e.g., a ruler or a scale), there is often some inherent error. The distribution of these errors, assuming
#                             they are normally distributed, allows for statistical assessment.
#
#     5. Daily Temperatures:
#
#                         Daily temperatures, when recorded over a long period, often exhibit a roughly normal distribution. The majority of days fall near the average temperature,
#                         with fewer extremely hot or cold days.
#
#     6. Grades in a Large Class:
#
#                                 In a large class, if the grading process is fair and unbiased, the distribution of grades tends to approximate a normal distribution.
#                                 Most students receive scores close to the class average, with fewer outliers at the extremes.
#
#     7. Income Distribution:
#
#                             In many countries, the distribution of incomes within the population can roughly follow a normal distribution. Most people earn around the median income,
#                             with fewer individuals at the very low or very high ends.
#
#     8. Stock Market Returns:
#
#                             The daily or annual returns of a well-diversified stock portfolio often exhibit a roughly normal distribution. This is a foundational assumption in
#                             financial modeling.
#
#     9.Test Scores:
#
#                 In educational testing, scores on standardized tests are often designed to follow a normal distribution. This helps in comparing a student's performance relative
#                 to a larger population.
#
#     10.Reaction Times:
#
#                     In experiments measuring human reaction times, the distribution of response times tends to approximate a normal distribution. Most people respond near the
#                     average time, with fewer outliers on the fast or slow ends.
#
#     11. Quality Control in Manufacturing:
#
#                                         In manufacturing, the distribution of product characteristics (e.g., weight, dimensions) can often be modeled using a normal distribution.
#                                         This is used in setting quality control limits.
#
#     12. Astronomical Observations:
#
#                                 In astronomy, observational errors due to various factors like equipment limitations, atmospheric conditions, and human error, often follow a normal
#                                 distribution.
#
#
#             These examples demonstrate how the normal distribution is a prevalent pattern in various aspects of the natural and human-made world, making it a crucial concept
#             in statistics and data analysis.

# %% [markdown]
# # Q.5 What is the Bernaulli Distribution? Give an example. What is the difference between Bernoulli Distribution and Binomial Distribution?

# %% [markdown]
# ## What is the Bernaulli Distribution?

# %% [raw]
# The Bernoulli distribution models a random experiment with two possible outcomes: success (1) and failure (0). It's used for situations like coin flips, where there are only
# two possible results. The parameter p represents the probability of success, and 1−p is the probability of failure. The mean (μ) is p and the variance (σ**2) is p(1−p).

# %% [markdown]
# ## Give an example.

# %% [raw]
# The Bernoulli distribution models a random experiment with two outcomes: success (1) and failure (0). For example, in a fair coin flip, p=0.5 for both heads and tails.
# The probability is 0 or 1

# %% [markdown]
# ## What is the difference between Bernoulli Distribution and Binomial Distribution?

# %% [raw]
# 1.Bernoulli Distribution:
#
#                             A.Single Trial:
#                                             The Bernoulli distribution models a single experiment or trial with two possible outcomes: success or failure.
#
#                             B.Parameter:
#                                         It is characterized by a parameter p, which represents the probability of success, and 1−p is the probability of failure.
#
#                             C.Example:
#                                         Tossing a coin (Heads as success, Tails as failure) is an example of a Bernoulli trial.
#
#
# 2.Binomial Distribution:
#
#                         A.Multiple Trials:
#                                             The Binomial distribution deals with a fixed number (n) of independent Bernoulli trials, each with the same probability of success (p).
#
#                         B.Parameters:
#                                     It is characterized by two parameters: n (the number of trials) and p (the probability of success in each trial).
#
#                         C.Outcome:
#                                     The random variable in a Binomial distribution represents the total number of successes out of n trials.
#
#                         D.Example:
#                                 If you flip a coin 10 times and count the number of Heads, that count follows a Binomial distribution.
#
#
# 3. Mathematical Formulas:
#
#                         A.Bernoulli Distribution:
#
#                                                     Probability of success (x=1):
#                                                                                     p^1⋅(1−p)^1−1=p
#
#                                                     Probability of failure (x=0):
#                                                                                     p^0⋅(1−p)^1−0=1−p
#
#
#                         B. Binomial Distribution:
#
#                                                     Probability of exactly k successes in n trials:
#                                                                                                     P(X=k)=(n/k)⋅p^k⋅(1−p)^n−k
#
#
#                                                         where (n/k) is a binomial coefficient, representing the number of ways to choose k successes out of n trials.
#
#
# In essence, the Bernoulli distribution is for a single "yes or no" experiment, while the Binomial distribution is used when you're interested in counting the number of successes
# in a fixed number of independent trials.
#
# For example, consider a single coin flip (Bernoulli) versus flipping a coin multiple times and counting the number of Heads (Binomial).
# The Bernoulli distribution is like looking at one flip, while the Binomial distribution considers the results of multiple flips.
#
#
#
#
# ***** Here are some additional points to further distinguish the Bernoulli and Binomial distributions:
#
# 1. Cumulative Probability:
#
#                            A.  In the Bernoulli distribution, there are only two possible outcomes (success or failure), so the cumulative distribution function (CDF)
#                                 can be calculated for each outcome individually.
#
#                            B. In the Binomial distribution, there are multiple possible values for the total number of successes, so the CDF gives the probability of getting up
#                                 to a certain number of successes.
#
#
# 2. Mean and Variance:
#
#                     A. For a Bernoulli distribution with parameter p, the mean (expected value) is E[X]=p and the variance is Var(X)=p(1−p).
#
#                     B. For a Binomial distribution with parameters n (number of trials) and p (probability of success), the mean is E[X]=np and the variance is Var(X)=np(1−p).
#
#
# 3. Shape of the Distribution:
#
#                             A. The Bernoulli distribution is a discrete probability distribution with only two possible outcomes, resulting in a probability mass function (PMF)
#                                 with two bars at x=0 and x=1.
#
#                             B. The Binomial distribution is also discrete but can have a more varied shape depending on the values of n and p. It tends to approximate
#                                 a normal distribution as n increases.
#
# 4. Application Examples:
#
#                         A. Bernoulli trials are often used to model situations with binary outcomes, such as success/failure, yes/no, or heads/tails.
#
#                         B. The Binomial distribution is applied in scenarios where you want to know the probability of a specific number of successes in a fixed number of repeated,
#                             independent Bernoulli trials. This can include situations like counting the number of defective items in a batch or the number of successful sales calls
#                             out of a certain number.
#
#
# 5. Relationship Between the Distributions:
#
#                                             The Binomial distribution can be thought of as the sum of n independent and identically distributed (i.i.d.) Bernoulli random variables.
#                                                 This is because in a Binomial scenario, you're essentially conducting n Bernoulli trials and counting the total number of successes.
#
#
#
# In summary, while the Bernoulli distribution models a single binary event, the Binomial distribution extends this concept to multiple independent trials,
# providing a framework for analyzing the total number of successes in those trials.

# %% [markdown]
# #  Q.6. Consider a dataset with a mean  of 50 and a standard deviation of 10.
# #   If we assume that the dataset is normally distributed, what is the Probability that a randomly selected observation will be greater than 60?
# #           Use the appropriate formula and show you calculations.

# %%
mean=50
std=10

# %%
z_score=(60-mean)/std

# %%
z_score
# Out:
# 1.0

# %%
# Area under the curve(60)= 0.8413
# Area is greater than 60=1-0.8413

# %%
1-0.8413
# Out:
# 0.15869999999999995

# %%
# So the probability that a randomly selected observation will be greater than 60 is 15.86%

# %% [markdown]
# # Q.7  Explain uniform Distribution with an example.

# %% [raw]
# The uniform distribution is a continuous probability distribution where all outcomes in a given interval are equally likely. It is named "uniform" because
# the probability density function (PDF) is constant or uniform over the entire range.
#
#             The probability density function of a continuous uniform distribution on the interval f(x)=1/(b-a) for a≤x≤b
#
#                 This means that any value within the interval [a,b] has an equal probability of occurring.
#
#             Example:
#
#                     Suppose you have a fair six-sided die. Each side has an equal chance of landing face up. This situation can be modeled by a discrete uniform distribution
#                     where each outcome (1, 2, 3, 4, 5, or 6) has a probability of 1/6.
#
#
#
#                 Now, let's extend this to a continuous uniform distribution:
#
#
#                 Example:
#
#                         Consider a random variable X representing the time it takes for a bus to arrive at a certain bus stop, and let's assume
#                         it follows a continuous uniform distribution between 1 and 10 minutes (a=1 minute, b=10 minutes).
#
#
#                         In this case, the probability density function f(x) for 1≤x≤10 minutes is:f(x)=1/(10-1)
#
#
#
#
#                         This means that the probability of the bus arriving in any particular minute between 1 and 10 is 1/9
#
#
#
# The uniform distribution is particularly useful in scenarios where all outcomes are equally likely, like in simulations, random number generation, and certain types of experiments
# where each outcome has the same likelihood of occurring.

# %% [raw]
# A...Properties of the Uniform Distribution:
#
# 1.Mean and Variance:
#
#                     For a continuous uniform distribution on the interval [a,b], the mean (μ) and variance (σ^2) are calculated as follows:
#                     μ= (a+b)/2
#                     σ^2= (b−a)^2/12
#
#
#                     These formulas tell us that the center of the distribution is at the midpoint of the interval, and the spread of the distribution is determined by
#                     the length of the interval.
#
# 2.Probability Density Function (PDF):
#
#                                     The PDF is a horizontal line segment with a constant height 1/(b-a)over the interval [a,b].
#
#
# 3.Cumulative Distribution Function (CDF):
#
#                                         The CDF is a linear function that starts from 0 at a and increases linearly to 1 at b. It is given by:
#                                         F(x)=(x-a)/(b-a)  for a≤x≤b
#
# 4.Independence:
#
#                 If X and Y are independent random variables with uniform distributions on [a,b] and [c,d] respectively, then X+Y will have a
#                 uniform distribution on the interval [a+c,b+d].
#
#
#
#            B.... Applications:
#
# 1.Simulation Studies:
#
#                         The uniform distribution is often used in computer simulations, especially when modeling situations where each outcome is equally likely.
#
#         2.Random Number Generation:
#
#                                     Many random number generators use algorithms based on the uniform distribution to generate pseudo-random numbers.
#
#                 3.Statistical Testing:
#
#                                     In statistical hypothesis testing, the uniform distribution can serve as a null hypothesis for various tests.
#
#                         4.Queueing Theory:
#
#                                         In the study of waiting lines and queueing systems, the uniform distribution may be used to model certain arrival or service time scenarios.
#
#                                 5.Game Theory:
#
#                                                 The uniform distribution can be used to model certain games and decision-making scenarios where each outcome is equally likely.
#
#
#
#
#
#     Understanding the properties and applications of the uniform distribution is essential in various fields of mathematics, statistics, computer science, and engineering.
#     It provides a simple but powerful tool for modeling situations where all outcomes are equally likely within a specified range.

# %% [raw]
# Transformations and Applications:
#
# 1.Transformations of Uniform Random Variables:
#
#                                                 Uniform random variables can be transformed into other distributions using mathematical transformations. For example,
#                                                 if U is a uniform random variable on [0,1], then a+bU follows a uniform distribution on the interval [a,a+b].
# 2.Monte Carlo Methods:
#
#                         Monte Carlo simulations heavily rely on generating random numbers, often using the uniform distribution. These simulations are used in various fields
#                         like finance, physics, engineering, and more for numerical approximation of complex systems.
# 3.Risk Assessment and Management:
#
#                                 In finance and insurance, the uniform distribution can be used to model uncertainty in certain scenarios, particularly when there's an equal
#                                 probability of an event occurring within a given range.
# 4.Machine Learning:
#
#                     In machine learning, the uniform distribution is sometimes used as a prior distribution in Bayesian methods or for generating initial values for certain algorithms.
#
# 5.Sampling Techniques:
#
#                         The uniform distribution is used as a foundation for generating random samples from other distributions. Various methods, like the inverse transform method
#                         or acceptance-rejection method, often rely on the uniform distribution.
#
# 6.Reliability Engineering:
#
#                             The uniform distribution can be used to model the time until a component or system fails when it is equally likely to fail at any point within
#                             a specified interval.
#
# 7.Environmental Modeling:
#
#                         In environmental modeling, the uniform distribution can be used to represent uncertainty in parameters when there is no prior information available.
#
# 8.Optimization Problems:
#
#                         The uniform distribution can be used in optimization problems, particularly in cases where it is assumed that the objective function is equally
#                         likely to achieve any value within a certain range.
#
#     These applications highlight the broad utility of the uniform distribution in various fields, showcasing its importance in modeling and simulating real-world phenomena.
#     Its simplicity and well-defined properties make it a valuable tool in probability theory and statistics.

# %% [markdown]
# #  Q.8  What is the Z-score? State the importance of the Z-score.

# %% [markdown]
# ## What is the Z-score?

# %% [raw]
# The Z-score, also known as the standard score or z-value, is a statistical measure that quantifies the relative position of a data point in a dataset.
#   It represents how many standard deviations a data point is from the mean of the dataset.
#
# A... Basic Understanding:
#
#                       The formula for calculating the Z-score of a data point
#
#                        x in a dataset with mean μ and standard deviation σ is:
#                             Z= (x-mui)/sigma
#
#
#             i). A positive Z-score indicates that the data point is above the mean, while a negative Z-score indicates it is below the mean.
#
#             ii). A Z-score of 0 means the data point is exactly at the mean of the dataset.
#
# The Z-score allows for comparisons between data points from different distributions, providing a standardized measure.

# %% [markdown]
# ## State the importance of the Z-score.

# %% [raw]
# The Z-score is important for several reasons:
#
#     1. Standardization of Data:
#
#                                 Z-scores allow for the standardization of data, making it easier to compare and analyze values from different distributions.
#
#     2. Outlier Detection:
#
#                         It helps identify outliers or unusual data points in a dataset, which can be crucial for quality control or anomaly detection.
#
#     3. Probability Calculations:
#
#                                 Z-scores are used to find probabilities associated with specific values in a normal distribution, enabling statistical inference.
#
#     4. Comparisons across Different Variables:
#
#                                             It enables meaningful comparisons between data points from different variables, even if they have different units or scales.
#
#     5. Quality Control in Manufacturing:
#
#                                         In industries, Z-scores are used to monitor and control processes, ensuring they stay within acceptable limits.
#
#     6.. Data Preprocessing in Machine Learning:
#
#                                                 Z-scores are employed to standardize or normalize features, making them compatible with algorithms sensitive to scale.
#
#     7.. Finance and Risk Assessment:
#
#                                     In finance, Z-scores are used to assess credit risk and to determine the financial health and stability of companies.
#
#      8. Multivariate Analysis:
#
#                                 Z-scores are extended to multivariate analysis, allowing for comparisons across different dimensions and variables.
#
#     9. Tolerance Intervals:
#
#                             Z-scores are used to construct tolerance intervals, providing a range of values within which a certain percentage of the data is expected to fall.
#
#     10. Robust Statistics:
#
#                             While Z-scores are widely used, they may be less effective for datasets with outliers or non-normal distributions. In such cases, robust alternatives are
#                             employed.
#
#
#
# Overall, the Z-score is a fundamental statistical tool that plays a crucial role in various fields, including statistics, finance, quality control, and machine learning.
# It provides a standardized measure for evaluating and interpreting data.

# %% [markdown]
# # Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.

# %% [raw]
# The Central Limit Theorem (CLT) states that when we add together a large number of independent random variables, regardless of their original distribution,
# the sum tends to follow a normal distribution. This is a fundamental concept in statistics and enables us to make inferences about populations based on sample data.

# %% [raw]
# The Central Limit Theorem (CLT) holds immense significance in statistics and various fields of science and engineering. Here are some key points highlighting its importance:
#
# 1. Foundation of Statistical Inference:
#                                         The CLT forms the basis for many statistical techniques. It allows us to make inferences about population parameters based on sample data.
#
# 2. Approximation of Distributions:
#                                     It provides a powerful tool to approximate the distribution of sums or averages of random variables, even when the original distribution is not known.
#
# 3. Normality in Large Samples:
#                                 It explains why the normal distribution frequently emerges in real-world applications. Many natural phenomena tend to exhibit approximately normal
#                                 behavior due to the influence of a large number of independent factors.
#
# 4. Hypothesis Testing:
#                         It enables hypothesis testing and confidence interval construction. These are fundamental tools for making decisions and drawing conclusions from data.
#
# 5. Quality Control and Process Improvement:
#                                         In industries, it's used for quality control and process improvement, helping to detect and address deviations from desired performance.
#
# 6. Economics and Finance:
#                         In economics and finance, the CLT is essential for modeling and analyzing data. It's used in areas like asset pricing, risk assessment, and option pricing.
#
# 7. Biostatistics and Epidemiology:
#                                 It plays a crucial role in medical research, allowing researchers to draw valid conclusions about the effects of treatments or interventions.
#
# 8. Psychology and Social Sciences:
#                                 It's widely applied in psychology and social sciences to draw inferences from data collected in experiments and surveys.
#
# 9. Machine Learning and Data Science:
#                                     The CLT is foundational in areas like machine learning and data science. It underpins many algorithms and techniques used in these fields.
#
# 10. Reliability Engineering:
#                             In engineering, particularly in reliability analysis, the CLT is used to model the behavior of complex systems consisting of many components.
#
# 11. Forecasting and Prediction:
#                                 It helps in making accurate forecasts and predictions in various fields including weather forecasting, demand forecasting, and more.
#
# In summary, the Central Limit Theorem is a fundamental concept in statistics that enables us to make reliable inferences and predictions based on data, and its applications
# span a wide range of disciplines.

# %% [markdown]
# # Q10: State the assumptions of the Central Limit Theorem.

# %% [raw]
# The Central Limit Theorem (CLT) is a fundamental result in probability theory and statistics. It states that, under certain conditions, the distribution of the sum (or average) of a large number of independent, identically distributed random variables approaches a normal distribution, regardless of the shape of the original distribution.
#
# The assumptions of the Central Limit Theorem are:
#
# 1. Independence:
#                 The random variables being summed or averaged must be independent. This means that the outcome of one variable should not affect the outcome of another.
#
# 2. Identical Distribution:
#                             The random variables should be identically distributed. This means they should have the same mean (μ) and standard deviation (σ).
#
# 3. Sample Size:
#                 The sample size should be sufficiently large. There is no strict rule for what constitutes "sufficiently large," but as a rule of thumb, a sample size of
#                 30 or greater is often considered large enough for the CLT to apply. However, for some distributions with heavy tails, a larger sample size may be necessary.
#
# 4. Finite Variance:
#                 The random variables should have finite variance. This means that the second moment of the distribution (i.e., the variance) should not be infinite.
#
# 5. Sum or Average:
#                 The Central Limit Theorem can apply to either the sum or the average of the random variables. If dealing with the sum, it's important that the sum doesn't
#                 grow too quickly with the sample size.
#
# 6. No Extreme Outliers:
#                     The original distribution should not have extreme outliers or heavy skewness. Extreme outliers can distort the convergence to a normal distribution.
#
# 7. No Strong Dependence:
#                         If there is dependence among the random variables, it should not be too strong. Strong dependence can inhibit the applicability of the CLT.
#
# It's important to note that while the Central Limit Theorem provides a powerful tool for approximating the distribution of sums or averages of random variables,
# it does not guarantee convergence in every situation. Some distributions, particularly those with very heavy tails, may not converge to a normal distribution even with a
# large sample size. In such cases, other techniques may be necessary.
